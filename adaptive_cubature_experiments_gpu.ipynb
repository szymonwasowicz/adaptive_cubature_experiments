# %% [markdown]
# ### Adaptive Cubature Experiments (GPU-Accelerated)
# This notebook utilizes **PyTorch** and **CUDA** to accelerate the adaptive subdivision process for higher-dimensional simplices. This is a GPU-optimized version of the `experiment_ndim` logic.

# %%
from adaptive_cubature_experiments_gpu import *

# %% [markdown]
# #### 4D Experiment: Unit Simplex on GPU
# Performing cubature in 4 dimensions. The GPU handles the simultaneous subdivision of thousands of simplices.

# %%
f = lambda x: 1 / (1 + torch.sum(x, dim=-1))
S = np.vstack([np.zeros(4), np.eye(4)])
epsilon=0.0001
exact_integral=5/36 - np.log(2)/6

experiment_gpu(f, S, epsilon, exact_integral)
